# %%
import cv2
import numpy as np
import os
from random import shuffle
from tqdm import tqdm
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = 'train_vehicles'
test_data = 'test_vehicles'
size = 64

# %%
def one_hot_label(img):
    if '100-lido' in img:
        ohl = np.array([1,0,0])
    elif '100-caff' in img:
        ohl = np.array([0,1,0])
    elif '50-50-lido-caff' in img:
        ohl = np.array([0,0,1])
    return ohl

# %%
def train_data_with_label():
    train_images = []
    for i in tqdm(os.listdir(train_data)):
        path = os.path.join(train_data, i)
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (size, size))
        train_images.append([np.array(img), one_hot_label(i)])
    shuffle(train_images)
    return train_images

# %%
def test_data_with_label():
    test_images = []
    for i in tqdm(os.listdir(test_data)):
        path = os.path.join(test_data, i)
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (size, size))
        test_images.append([np.array(img), one_hot_label(i)])
    return test_images

# %%
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import *
# Out:
# Using TensorFlow backend.

# %%
training_images = train_data_with_label()
testing_images = test_data_with_label()

tr_img_data = np.array([i[0] for i in 
                        training_images]).reshape(-1, 64, 64, 1)
tr_lbl_data = np.array([i[1] for i in training_images])

tst_img_data = np.array([i[0] for i in 
                        testing_images]).reshape(-1, 64, 64, 1)
tst_lbl_data = np.array([i[1] for i in testing_images])
# Out:
# 100%|██████████| 200/200 [00:02<00:00, 94.92it/s]
# 100%|██████████| 52/52 [00:00<00:00, 170.82it/s]

# %%
model = Sequential()

model.add(InputLayer(input_shape=[size,size,1]))
model.add(Conv2D(filters=32,kernel_size=5,strides=1,padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=5,padding='same'))

model.add(Conv2D(filters=50,kernel_size=5,strides=1,padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=5,padding='same'))

model.add(Conv2D(filters=80,kernel_size=5,strides=1,padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=5,padding='same'))

model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(2,activation='softmax'))
optimizer = Adam(lr=1e-2)

model.compile(optimizer=optimizer, loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x=tr_img_data,y=tr_lbl_data,epochs=50,batch_size=100)
model.summary()
# Out:
# Epoch 1/50
# 200/200 [==============================] - 1s 3ms/step - loss: 50.7492 - accuracy: 0.5050
# Epoch 2/50
# 200/200 [==============================] - 0s 1ms/step - loss: 6.4773 - accuracy: 0.5000
# Epoch 3/50
# 200/200 [==============================] - 0s 1ms/step - loss: 1.5188 - accuracy: 0.5100
# Epoch 4/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.5600
# Epoch 5/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.5100
# Epoch 6/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6843 - accuracy: 0.5900
# Epoch 7/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6712 - accuracy: 0.5950
# Epoch 8/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6216 - accuracy: 0.6150
# Epoch 9/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6091 - accuracy: 0.6850
# Epoch 10/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5848 - accuracy: 0.7050
# Epoch 11/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5801 - accuracy: 0.7100
# Epoch 12/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5604 - accuracy: 0.7450
# Epoch 13/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5608 - accuracy: 0.7250
# Epoch 14/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5571 - accuracy: 0.7150
# Epoch 15/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5349 - accuracy: 0.7500
# Epoch 16/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5158 - accuracy: 0.7300
# Epoch 17/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4865 - accuracy: 0.7850
# Epoch 18/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5013 - accuracy: 0.7850
# Epoch 19/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4585 - accuracy: 0.8100
# Epoch 20/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4385 - accuracy: 0.8100
# Epoch 21/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4079 - accuracy: 0.8350
# Epoch 22/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4217 - accuracy: 0.8250
# Epoch 23/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5188 - accuracy: 0.7800
# Epoch 24/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4075 - accuracy: 0.8350
# Epoch 25/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4283 - accuracy: 0.8200
# Epoch 26/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3389 - accuracy: 0.8650
# Epoch 27/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4375 - accuracy: 0.8050
# Epoch 28/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6995 - accuracy: 0.7350
# Epoch 29/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4558 - accuracy: 0.7850
# Epoch 30/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4773 - accuracy: 0.7700
# Epoch 31/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.5183 - accuracy: 0.7650
# Epoch 32/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4952 - accuracy: 0.7950
# Epoch 33/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4264 - accuracy: 0.8100
# Epoch 34/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3545 - accuracy: 0.8450
# Epoch 35/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4254 - accuracy: 0.8100
# Epoch 36/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8250
# Epoch 37/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3378 - accuracy: 0.8550
# Epoch 38/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3052 - accuracy: 0.8900
# Epoch 39/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3040 - accuracy: 0.8850
# Epoch 40/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2723 - accuracy: 0.9000
# Epoch 41/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2401 - accuracy: 0.9100
# Epoch 42/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2471 - accuracy: 0.8950
# Epoch 43/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2138 - accuracy: 0.9250
# Epoch 44/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2170 - accuracy: 0.9100
# Epoch 45/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2156 - accuracy: 0.9150
# Epoch 46/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1891 - accuracy: 0.9400
# Epoch 47/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2022 - accuracy: 0.9300
# Epoch 48/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2468 - accuracy: 0.9100
# Epoch 49/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1859 - accuracy: 0.9250
# Epoch 50/50
# 200/200 [==============================] - 0s 1ms/step - loss: 0.1870 - accuracy: 0.9300
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_58 (Conv2D)           (None, 64, 64, 32)        832
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 13, 13, 50)        40050
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 3, 3, 50)          0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 3, 3, 80)          100080
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 1, 1, 80)          0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 1, 1, 80)          0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 80)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 512)               41472
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 183,460
# Trainable params: 183,460
# Non-trainable params: 0
# _________________________________________________________________

# %%
fig=plt.figure(figsize=(14,14))

for cnt, data in enumerate(testing_images[0:30]):
    y = fig.add_subplot(6, 5, cnt+1)
    img = data[0]
    data = img.reshape(1, size, size, 1)
    model_out = model.predict([data])
    if np.argmax(model_out) == 1:
        str_label='Truck'
    else:
        str_label='Car'
    y.imshow(img, cmap='gray')
    plt.title(str_label)
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)
